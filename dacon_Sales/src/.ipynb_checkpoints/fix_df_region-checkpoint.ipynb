# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import operator
import sys
# %matplotlib inline

# %%
os.listdir('../input/')
# Out:
# ['funda_train.csv', 'submission.csv']

# %%
df = pd.read_csv('../input/funda_train.csv')

# %%
df.head(5)
# Out:
#    store_id  card_id card_company transacted_date transacted_time  \
# 0         0        0            b      2016-06-01           13:13
# 1         0        1            h      2016-06-01           18:12
# 2         0        2            c      2016-06-01           18:52
# 3         0        3            a      2016-06-01           20:22
# 4         0        4            c      2016-06-02           11:06
#
#    installment_term region type_of_business       amount
# 0                 0    NaN           기타 미용업  1857.142857
# 1                 0    NaN           기타 미용업   857.142857
# 2                 0    NaN           기타 미용업  2000.000000
# 3                 0    NaN           기타 미용업  7857.142857
# 4                 0    NaN           기타 미용업  2000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6556613 entries, 0 to 6556612
# Data columns (total 9 columns):
# store_id            int64
# card_id             int64
# card_company        object
# transacted_date     object
# transacted_time     object
# installment_term    int64
# region              object
# type_of_business    object
# amount              float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 450.2+ MB

# %%
max(df['store_id'].values), max(df['card_id'].values), max(df['installment_term'])
# Out:
# (2136, 4663856, 93)

# %%
df['store_id'] = df['store_id'].astype(np.int16)
df['installment_term'] = df['installment_term'].astype(np.int16)

# %%
#sns.heatmap(df.isnull(), cbar=False)

# %%
def split_data(x, idx, seg):
    if type(x) is str:
        return x.split(seg)[idx]
    return None

# %% [markdown]
# ## transacted_year

# %%
df['transacted_year'] = df['transacted_date'].apply(split_data, args=[0, '-'])
df['transacted_month'] = df['transacted_date'].apply(split_data, args=[1, '-'])

# %%
df['transacted_hour'] = df['transacted_time'].apply(split_data, args=[0, ':'])
df['transacted_hour'] = df['transacted_hour'].astype(np.int16)

# %% [markdown]
# ## type_of_business

# %%
df['type_big'] = df['type_of_business'].apply(split_data, args=[-1, ' '])

# %%
len(df['type_big'].unique()), len(df['type_of_business'].unique()), len(df[df['type_big'].isnull()]['store_id'].unique())
# Out:
# (40, 146, 1175)

# %%
#1961개 가게중 1169개 가게의 type_of_business가 결측값이다.
#대부분 결측값
len(df['store_id'].unique())
# Out:
# 1967

# %%
df[df['store_id']==1]['amount'].mean()
# Out:
# 970.0271964946741

# %%
df[df['store_id']==1]['transacted_hour'].mean()
# Out:
# 14.484664198836594

# %%
df.groupby(['type_big']).agg({'transacted_hour':lambda x:x.value_counts().index[0]}).sort_values(by='transacted_hour')
#df.groupby(['type_big']).agg({'transacted_hour':'mean'}).sort_values(by='transacted_hour')
# Out:
#           transacted_hour
# type_big
# 택배업                     8
# 컨설팅업                    9
# 한의원                    11
# 병원                     11
# 제과점업                   12
# 재배업                    12
# 임대업                    12
# 제조업                    13
# 세차업                    13
# 음료점업                   13
# 의원                     14
# 공사업                    14
# 복제업                    14
# 판매업                    15
# 촬영업                    15
# 도매업                    15
# 이용업                    16
# 수리업                    16
# 여행사업                   16
# 외국어학원                  17
# 서비스업                   17
# 소매업                    17
# 미용업                    17
# 예술학원                   17
# 교육기관                   17
# 학원                     18
# 편의점                    18
# 세탁업                    18
# 슈퍼마켓                   18
# 교습학원                   18
# 직업훈련학원                 18
# 여관업                    18
# 연구개발업                  19
# 예식장업                   20
# 음식점업                   20
# 전문점                    21
# 운영업                    21
# 주점업                    23
# 마사지업                   23

# %%
df.groupby(['type_big']).agg({'amount':[lambda x:x.value_counts().index[0],'mean', 'std', 'min', 'max']}).sort_values([('amount', 'mean')])
# Out:
#                 amount                                              \
#               <lambda>           mean            std           min
# type_big
# 제과점업        357.142857     913.737800    1104.842172 -7.042857e+03
# 의원          700.000000    1406.982724    1963.882901 -6.285714e+03
# 편의점         642.857143    1593.218107    2865.938897 -3.800000e+04
# 음료점업        857.142857    1970.210406   13852.538387 -3.571429e+05
# 택배업         785.714286    2524.867264    8601.840094 -2.702857e+04
# 슈퍼마켓       1285.714286    2723.382724    4072.338801 -1.410000e+04
# 복제업        2142.857143    3131.555624    2354.688320 -8.571429e+03
# 세탁업        1428.571429    3405.912195    5723.867703 -2.922857e+04
# 재배업        1428.571429    3467.160432    4193.157024 -9.142857e+03
# 이용업        1857.142857    4067.985476    4912.706323 -4.285714e+04
# 전문점        2857.142857    4390.203856   15104.369736 -2.857143e+05
# 한의원        2142.857143    4806.961793   12687.063755 -1.000000e+05
# 세차업        5000.000000    4992.481593   12790.568545 -5.285714e+04
# 음식점업       1714.285714    6485.968045   12398.314695 -8.571429e+05
# 미용업        1428.571429    6707.035179   14752.798327 -9.000000e+05
# 주점업        3857.142857    6794.422451   11770.535947 -1.714286e+05
# 임대업        2142.857143    7798.130692   26727.825500 -4.571429e+04
# 공사업        5000.000000   11128.005340   21866.035090 -1.071429e+05
# 여관업        4285.714286   11361.911761   23224.377119 -6.285714e+05
# 마사지업       8571.428571   12527.319575   22300.573743 -3.285714e+05
# 소매업        4285.714286   12722.186479   31180.644472 -1.428571e+06
# 운영업        2857.142857   13148.589169   30645.034988 -7.142857e+05
# 제조업       42857.142857   17769.494050   38711.260225 -2.571429e+05
# 직업훈련학원    17142.857143   18479.458337   11283.158667 -5.142857e+04
# 서비스업       4285.714286   20096.066609   40349.317207 -7.857143e+05
# 수리업        5714.285714   22465.870785   70813.815938 -6.118571e+05
# 예술학원      17142.857143   26410.690262   31339.236040 -1.542857e+05
# 판매업        4714.285714   30942.576508   52472.665637 -1.571429e+06
# 촬영업        2142.857143   31479.387218   44999.122249 -2.700000e+05
# 교육기관      17142.857143   31661.480497   46617.116414 -1.142857e+06
# 연구개발업     21428.571429   40031.085319   31004.511064 -1.157143e+05
# 도매업        2857.142857   40535.950118  145920.459459 -2.000000e+06
# 교습학원      57142.857143   44540.930648   46903.569532 -3.785714e+05
# 학원        35714.285714   46929.809265   40036.366913 -6.428571e+05
# 외국어학원     35714.285714   50870.048130   55581.609136 -6.000000e+05
# 예식장업        714.285714   53733.137202  217794.679216 -8.642857e+05
# 여행사업      85714.285714   83472.060730  139089.065465 -1.142857e+06
# 병원        42857.142857  135287.727565   90847.339946 -4.993857e+05
# 컨설팅업      39285.714286  150819.538148  196114.489375 -2.771429e+05
#
#
#                    max
# type_big
# 제과점업      5.000000e+04
# 의원        2.571429e+04
# 편의점       5.000000e+04
# 음료점업      7.142857e+05
# 택배업       3.399000e+05
# 슈퍼마켓      1.428571e+05
# 복제업       3.214286e+04
# 세탁업       4.285714e+05
# 재배업       5.485714e+04
# 이용업       8.571429e+04
# 전문점       1.527429e+06
# 한의원       1.500000e+05
# 세차업       5.714286e+05
# 음식점업      1.357429e+06
# 미용업       9.000000e+05
# 주점업       7.857143e+05
# 임대업       1.257143e+06
# 공사업       2.428571e+05
# 여관업       7.057143e+05
# 마사지업      3.428571e+05
# 소매업       1.571429e+06
# 운영업       1.285714e+06
# 제조업       7.142857e+05
# 직업훈련학원    1.028571e+05
# 서비스업      1.185714e+06
# 수리업       3.038205e+06
# 예술학원      6.514286e+05
# 판매업       1.623999e+06
# 촬영업       4.000000e+05
# 교육기관      1.142857e+06
# 연구개발업     2.595000e+05
# 도매업       5.571429e+06
# 교습학원      9.428571e+05
# 학원        8.571429e+05
# 외국어학원     1.214286e+06
# 예식장업      2.142857e+06
# 여행사업      1.197857e+06
# 병원        1.041600e+06
# 컨설팅업      7.857143e+05

# %% [markdown]
# ## region

# %%
def check_store_region(store_id):
    #해당 가게 데이터를 가져온다
    store = df[df['store_id']==store_id][['region', 'card_id']]
    region_dict = {}
    #지역이 None이면
    if sum(store['region'].isnull()):
        #해당 가게에서 사용되 card_id를 확인
        store_card_id = store['card_id'].unique()
        #각 card_id에서
        for card_id in store_card_id:
            #해당 card_id가 사용된 지역들을 찾는다.
            regions = df[df['card_id']==card_id]['region'].unique()
            #각 지역을 region_dict에 추가한다
            for region in regions:
                if region not in region_dict:
                    region_dict[region] = 1
                else:
                    region_dict[region] += 1
    region_dict.pop(np.nan, None)
    return region_dict

# %%
#같은 값을 가지는 값이 있을 수 있다.
#대도시를 중심으로 대도시의 수에 따라 각 값에 가중치를 더한다.
#부산 금정구:1, 부산 동래구:1, 서울 용인구:1 -> 부산 금정구:1+2, 부산 동래구:1+2, 서울 용인구:1+1
def add_weight_by_region(region_dict):
    weight = {}
    for key in region_dict.keys():
        key = key.split(' ')[0]
        weight[key] = 1 + weight.get(key, 0)
    for key in region_dict.keys():
        region_dict[key] += weight[key.split(' ')[0]]
    return region_dict

# %%
def find_region(store_id):
    #해당 매장에서 결제된 고객들의 카드가 사용된 지역
    region_dict = check_store_region(store_id)
    #지역이 존재하면
    if len(region_dict)>0:
        #대도시 기준 가중치 부여
        region_dict = add_weight_by_region(region_dict)
        #지역과 최대값을 찾는다
        max_region = max(region_dict.items(), key=operator.itemgetter(1))
        #같은 값을 가지는 오차가 존재 할 가능성이 있으나, 앞의 가중치 부여로 어느정도 보정을 하였기 때문에
        #따로 수정하지는 않는다.
        return max_region[0]
    return np.nan

# %%
len(df[~df['region'].isnull()]['store_id'].unique()), len(df['store_id'].unique())
#총 1967 데이터 중 1277개 데이터가 비어있다.
# Out:
# (1277, 1967)

# %%
region_null_stores = df[df['region'].isnull()]['store_id'].unique()
for step, store_id in enumerate(region_null_stores):
    val = find_region(store_id)
    df.loc[df['store_id'] == store_id, 'region'] = val
    print("[*]{:>6}% completed".format((100*step/len(region_null_stores))), end="\r", flush=True)
# Out:
# [*]99.85507246376811% completeddd

# %%
df.isnull().sum()
# Out:
# store_id                  0
# card_id                   0
# card_company              0
# transacted_date           0
# transacted_time           0
# installment_term          0
# region                 8321
# type_of_business    3952609
# amount                    0
# transacted_year           0
# transacted_month          0
# transacted_hour           0
# type_big            3952609
# dtype: int64

# %%
#데이터를 순회하며 지역의 결측값을 채울 때, 데이터가 부족하면 None으로 채워진다.
#이럴 경우, 해당 가게에서 사용된 card_id가 다른 매장에서 사용된 경우가 없는 경우이다.
#이를 확인하는 코드.
for store_id in df[df['region'].isnull()].store_id.unique():
    print('>>store_id : {}'.format(store_id))
    card_id_list = df[df['store_id']==store_id]['card_id'].unique()
    for card_id in card_id_list:
        unique_store_id = df[df['card_id']==card_id]['store_id'].unique()
        if len(unique_store_id) is not 1:
            print('!!{} - {} - {}'.format(store_id, card_id, unique_store_id))
# Out:
# >>store_id : 95
# !!95 - 234158 - [  95 1185]
# !!95 - 234267 - [  95 1513]
# >>store_id : 125
# !!125 - 297417 - [ 125 1950]
# !!125 - 297500 - [125 557]
# >>store_id : 314
# >>store_id : 481
# >>store_id : 564
# >>store_id : 952
# >>store_id : 1351
# >>store_id : 1365

# %%
#새로 채워넣은 데이터를 바탕으로 한번 더 region의 결측값을 채운다
region_null_stores_2nd = df[df['region'].isnull()]['store_id'].unique()
for step, store_id in enumerate(region_null_stores_2nd):
    val = find_region(store_id)
    df.loc[df['store_id'] == store_id, 'region'] = val
    print("[*]{:.2} % completed".format(100*step/len(region_null_stores_2nd)), end="\r", flush=True)
# Out:
# [*]8.8e+01 % completed

# %%
#여기서 나오는 store_id에서 사용된 card_id는 다른 곳에서 사용된 기록이 없다.
#이 특징들을 살펴보자.
for store_id in df[df['region'].isnull()].store_id.unique():
    print('>>store_id : {}'.format(store_id))
    card_id_list = df[df['store_id']==store_id]['card_id'].unique()
    for card_id in card_id_list:
        unique_store_id = df[df['card_id']==card_id]['store_id'].unique()
        if len(unique_store_id) is not 1:
            print('!!{} - {} - {}'.format(store_id, card_id, unique_store_id))
# Out:
# >>store_id : 314
# >>store_id : 481
# >>store_id : 564
# >>store_id : 952
# >>store_id : 1351
# >>store_id : 1365

# %%
#해당 데이터는 region, type_of_business가 모두 결측값
df[df['store_id'].isin(df[df['region'].isnull()].store_id.unique())].groupby(['store_id']).agg({'region':'count','type_of_business':'count'})
# Out:
#           type_of_business  region
# store_id
# 314                      0       0
# 481                      0       0
# 564                      0       0
# 952                      0       0
# 1351                     0       0
# 1365                     0       0

# %%
for store_id in df[df['region'].isnull()].store_id.unique():
    df = df.drop(df[df['store_id']==store_id].index)

# %%
df['region_big'] = df['region'].apply(split_data, args=[0, ' '])
df['region_detail'] = df['region'].apply(split_data, args=[1, ' '])

# %%
df.isnull().sum()
# Out:
# store_id                  0
# card_id                   0
# card_company              0
# transacted_date           0
# transacted_time           0
# installment_term          0
# region                    0
# type_of_business    3946176
# amount                    0
# transacted_year           0
# transacted_month          0
# transacted_hour           0
# type_big            3946176
# region_big                0
# region_detail             0
# dtype: int64

# %%
df.to_csv('df_fixed.csv')

# %%
df = pd.read_csv('df_fixed.csv')
df.head(5)
# Out:
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  store_id  card_id card_company transacted_date transacted_time  \
# 0           0         0        0            b      2016-06-01           13:13
# 1           1         0        1            h      2016-06-01           18:12
# 2           2         0        2            c      2016-06-01           18:52
# 3           3         0        3            a      2016-06-01           20:22
# 4           4         0        4            c      2016-06-02           11:06
#
#    installment_term  region type_of_business       amount  transacted_year  \
# 0                 0  서울 광진구           기타 미용업  1857.142857             2016
# 1                 0  서울 광진구           기타 미용업   857.142857             2016
# 2                 0  서울 광진구           기타 미용업  2000.000000             2016
# 3                 0  서울 광진구           기타 미용업  7857.142857             2016
# 4                 0  서울 광진구           기타 미용업  2000.000000             2016
#
#    transacted_month  transacted_hour type_big region_big region_detail
# 0                 6               13      미용업         서울           광진구
# 1                 6               18      미용업         서울           광진구
# 2                 6               18      미용업         서울           광진구
# 3                 6               20      미용업         서울           광진구
# 4                 6               11      미용업         서울           광진구

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# store_id                  0
# card_id                   0
# card_company              0
# transacted_date           0
# transacted_time           0
# installment_term          0
# region                    0
# type_of_business    3946176
# amount                    0
# transacted_year           0
# transacted_month          0
# transacted_hour           0
# type_big            3946176
# region_big                0
# region_detail             0
# dtype: int64

# %%
#df.groupby(['type_big']).agg({'amount':['mean', 'std', 'min', 'max']}).sort_values([('amount', 'mean')])
#df.groupby(['type_big']).agg({'transacted_hour':'mean'}).sort_values(by='transacted_hour')

# %%
df_copy = df[['store_id', 'amount', 'transacted_hour', 'type_big']]
df_copy = df_copy.groupby('store_id').agg({'transacted_hour':lambda x:x.value_counts().index[0],
                                          'amount': 'mean',
                                          'type_big':pd.Series.unique})
df_copy.head(3)
# Out:
#                 amount  transacted_hour type_big
# store_id
# 0          5394.883157               18      미용업
# 1           970.027196               14      NaN
# 2         15142.123288               16      NaN

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler, RobustScaler
# Create instance (i.e. object) of the standard scaler
#scaler = StandardScaler()
scaler = MinMaxScaler()
#scaler = RobustScaler()
df_copy[['amount', 'transacted_hour']] = scaler.fit_transform(df_copy[['amount', 'transacted_hour']])

# %%
x_train = df_copy[~df_copy['type_big'].isnull()][['amount', 'transacted_hour']]
y_train = df_copy[~df_copy['type_big'].isnull()][['type_big']]
x_test =  df_copy[df_copy['type_big'].isnull()][['amount', 'transacted_hour']]
y_test =  df_copy[df_copy['type_big'].isnull()][['type_big']]

# %%
df_copy.head(3)
# Out:
#             amount  transacted_hour type_big
# store_id
# 0         0.013517         0.782609      미용업
# 1         0.001019         0.608696      NaN
# 2         0.041050         0.695652      NaN

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=1)
neigh.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %%
plt.figure(figsize=(16, 16))
ax = sns.scatterplot(x="transacted_hour", y="amount", hue="type_big",
                      data=df_copy[:1000])

# %%
x_test.head(3)
# Out:
#             amount  transacted_hour
# store_id
# 1         0.001167         0.608696
# 2         0.016667         0.695652
# 4         0.008667         0.826087

# %%
neigh.predict([x_test.iloc[0,:]])
# Out:
# array(['음료점업'], dtype=object)

# %%
df_copy.groupby(['type_big']).agg({'transacted_hour':lambda x:x.value_counts().index[0]}).sort_values(by='transacted_hour')
# Out:
#           transacted_hour
# type_big
# 택배업              0.347826
# 컨설팅업             0.391304
# 한의원              0.478261
# 병원               0.478261
# 제과점업             0.521739
# 재배업              0.521739
# 임대업              0.521739
# 음료점업             0.565217
# 의원               0.608696
# 공사업              0.608696
# 복제업              0.608696
# 세차업              0.608696
# 소매업              0.652174
# 판매업              0.652174
# 촬영업              0.652174
# 도매업              0.652174
# 수리업              0.695652
# 교육기관             0.695652
# 제조업              0.695652
# 외국어학원            0.739130
# 여행사업             0.739130
# 교습학원             0.739130
# 예술학원             0.739130
# 서비스업             0.739130
# 편의점              0.782609
# 직업훈련학원           0.782609
# 세탁업              0.782609
# 미용업              0.782609
# 여관업              0.782609
# 슈퍼마켓             0.782609
# 이용업              0.782609
# 학원               0.826087
# 연구개발업            0.826087
# 음식점업             0.869565
# 예식장업             0.869565
# 전문점              0.913043
# 운영업              0.956522
# 주점업              1.000000
# 마사지업             1.000000

# %%
df_copy.groupby(['type_big']).agg({'amount':[lambda x:x.value_counts().index[0]]}).sort_values([('amount','<lambda>')])
# Out:
#             amount
#           <lambda>
# type_big
# 제과점업      0.000833
# 음료점업      0.001000
# 편의점       0.001500
# 의원        0.001633
# 예식장업      0.001667
# 택배업       0.001833
# 슈퍼마켓      0.003000
# 재배업       0.003333
# 운영업       0.003333
# 세탁업       0.003333
# 서비스업      0.004000
# 미용업       0.004000
# 이용업       0.004000
# 음식점업      0.004667
# 복제업       0.005000
# 임대업       0.005000
# 촬영업       0.005000
# 한의원       0.005000
# 주점업       0.005333
# 전문점       0.006667
# 소매업       0.010000
# 여관업       0.010000
# 공사업       0.011667
# 세차업       0.011667
# 수리업       0.016667
# 마사지업      0.020000
# 예술학원      0.036667
# 직업훈련학원    0.040000
# 교육기관      0.040000
# 연구개발업     0.050000
# 판매업       0.066667
# 학원        0.066667
# 외국어학원     0.083333
# 컨설팅업      0.091667
# 병원        0.100000
# 제조업       0.100000
# 교습학원      0.100000
# 여행사업      0.200000
# 도매업       0.333333

# %%
#16년 6월 ~ 19년 2월의 데이터 (33달)
#19년 2월 ~ 19년 5월의 가게별 총 판매금액 예측

# %% [markdown]
# 사용할 데이터 개수 = 가게 수 * 월별 데이터 = 1967 * 33 = 64911<br/>
# <br/>
# **월별 데이터**<br/>
# Target Data<br/>
# --> amount<br/>
# Train Data<br/>
# --> year<br/>
# --> month<br/>
# --> amount -> lag features<br/>
# --> amount의 전체평균에 대한 변화량 -> lag features<br/>
# --> amount의 해당 월 평균에 대한 변화량 -> lag features<br/>
# --> type_of_business의 전체평균에 대한 변화량 -> lag features<br/>
# --> type_of_business의 해당 월 평균에 대한 변화량 -> lag features<br/>
